# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.worldometers.info/population/countries-in-asia-by-population/'
response = requests.get (url)
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup (response.text,'lxml')
print(soup.prettify()[:500])
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Asian Countries by Population (2025) - Worldometer
#   </title>
#   <meta content="List of countries (or dependencies) in Asia ranked by populat

# %%
table = soup.find ('table',id = 'example2')
headers = table.find_all ('th')
titles = []
for i in headers:
  title = i.text
  titles.append (title)

print(titles)
# Out:
# ['#', 'Country (or dependency)', 'Population (2024)', 'Yearly Change', 'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)', 'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share']

# %%
df = pd.DataFrame (columns = titles)
df
# Out:
# Empty DataFrame
# Columns: [#, Country (or dependency), Population (2024), Yearly Change, Net Change, Density (P/Km²), Land Area (Km²), Migrants (net), Fert. Rate, Med. Age, Urban Pop %, World Share]
# Index: []

# %%
rows = table.find_all ('tr')
for i in rows [1:]:
  data = i.find_all ('td')
  row = [tr.text.strip() for tr in data]
  l = len (df)
  df.loc [l] = row

df
# Out:
#       # Country (or dependency) Population (2024) Yearly Change  Net Change  \
# 0     1                   India     1,450,935,791        0.89 %  12,866,195
# 1     2                   China     1,419,321,278       -0.23 %  -3,263,655
# 2     3               Indonesia       283,487,931        0.82 %   2,297,864
# 3     4                Pakistan       251,269,164        1.52 %   3,764,669
# 4     5              Bangladesh       173,562,364        1.22 %   2,095,374
# ..   ..                     ...               ...           ...         ...
# 148  47                  Cyprus         1,358,282        0.99 %      13,306
# 149  48                  Bhutan           791,524        0.65 %       5,139
# 150  49                   Macao           720,262        0.89 %       6,350
# 151  50                Maldives           527,799        0.34 %       1,805
# 152  51                  Brunei           462,721        0.82 %       3,772
#
# ...

# %%
df.to_csv(r"C:\Users\Administrator\OneDrive\Documents\WebscrapingFiles\Asian Countries by Population.csv",index = False)
