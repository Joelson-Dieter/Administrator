# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.worldometers.info/gdp/canada-gdp/'
response = requests.get (url)
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup (response.text ,'lxml')
print(soup.prettify()[:150])
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <

# %%
table = soup.find ('table',class_='table table-striped table-bordered table-hover table-condensed table-list')
headers = table.find_all ('th')
titles = []
for i in headers:
  title = i.text
  titles.append (title)
  
df = pd.DataFrame (columns = titles)
df
# Out:
# Empty DataFrame
# Columns: [Year, GDP Nominal (Current USD) , GDP Real  (Inflation adj.) , GDP change, GDP per capita, Pop. change, Population]
# Index: []

# %%
rows = table.find_all ('tr')
for i in rows [1:]:
  data = i.find_all ('td')
  row = [tr.text for tr in data]
  l = len (df)
  df.loc [l] = row

df
# Out:
#      Year GDP Nominal (Current USD)  GDP Real  (Inflation adj.)  GDP change  \
# 0    2022         $2,139,840,000,000          $1,748,360,000,000      3.40%
# 1    2021         $2,001,490,000,000          $1,690,930,000,000      5.01%
# 2    2020         $1,647,600,000,000          $1,610,230,000,000     -5.07%
# 3    2019         $1,743,730,000,000          $1,696,310,000,000      1.89%
# 4    2018         $1,725,300,000,000          $1,664,870,000,000      2.78%
# ..    ...                        ...                         ...        ...
# 148  1997           $654,988,000,000          $1,012,650,000,000      4.28%
# 149  1996           $630,598,000,000            $971,087,000,000      1.62%
# 150  1995           $605,941,000,000            $955,614,000,000      2.69%
# 151  1994           $579,944,000,000            $930,545,000,000      4.49%
# 152  1993           $579,059,000,000            $890,521,000,000      2.66%
#
#     GDP per capita Pop. change  Population
# 0          $45,036      0.95 %  38,821,259
# 1          $43,973      0.74 %  38,454,057
# 2          $42,184      1.03 %  38,171,902
# 3          $44,896      1.31 %  37,782,935
# 4          $44,641      1.32 %  37,295,005
# ..             ...         ...         ...
# 148        $33,689      0.98 %  30,059,089
# 149        $32,623      1.05 %  29,767,206
# 150        $32,439      1.07 %  29,459,131
# 151        $31,926      1.10 %  29,147,381
# 152        $30,888      1.16 %  28,830,637
#
# [153 rows x 7 columns]

# %%
df.to_csv (r"C:\Users\Administrator\OneDrive\Documents\WebscrapingFiles\GDP Of Canada.csv",index = False)
