# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://www.hwestauctions.com/schedule.v4.php'
page = requests.get (url)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup (page.text,'lxml')
soup.find_all ('table')[2]
soup.find_all ('table',class_="sorttable_sorted")
table = soup.find_all ('table')[2]
soup.find_all ('tr')
headers = table.find_all ('tr')
titles = []
for i in headers:
  title = i.text
  titles.append (title)
  
df = pd.DataFrame (columns = titles)

# %%
df
# Out:
# Empty DataFrame
# Columns: [
# Sale Time
# Deposit (in $k,000)
# Address
# City
# Zip
# Sale Location
# AD First Pub
# Links
# ,
# 2025-01-02 10:00 AM
# $20K
# 12963 WALSH LANE
# LUSBY
# 20657
#
# 	CALVERT COURTHOUSE AT 175 MAIN ST, PRINCE FREDERICK, MD 20678
# 12/13/2024
# SATELLITE / MAP VIEW PUBLICATION
# ,
# 2025-01-02 11:30 AM
# $20K
# 42264 RIDGE ROAD
# MECHANICSVILLE
# 20659
#
# 	ST MARYS COURTHOUSE AT 41605 COURTHOUSE DRIVE, LEONARDTOWN, MD 20650
# 12/13/2024
# SATELLITE / MAP VIEW PUBLICATION
# ,
# 2025-01-02 1:00 PM
# $5K
# 11207A BARNSWALLOW PLACE
# WALDORF
# 20603
#
# 	CHARLES COURTHOUSE AT 200 CHARLES STREET ( IN THE BREEZEWAY BETWEEN CIRCUIT AND DISTRICT COURTS ), LA PLATA, MD 20646
# 12/16/2024
# SATELLITE / MAP VIEW PUBLICATION
# ,
# 2025-01-02 2:00 PM
# $20K
# 5415 KIRBY ROAD
# CLINTON
# 20735
#
# 	PRINCE GEORGES COURTHOUSE AT FRONT OF THE DUVAL WING OF THE COURTHOUSE COMPLEX 14735 MAIN ST, UPPER MARLBORO, MD 20772
# 12/16/2024
# SATELLITE / MAP VIEW PUBLICATION
# ,
# ...

# %%
rows = table.find_all ('td')
for i in rows [1:]:
  data = i.find_all ('tr')
  rows = [tr.text for tr in data]
  l = len (df)
  df.loc [l] = rows
  print (df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[250], line 6
#       4 rows = [tr.text for tr in data]
#       5 l = len (df)
# ----> 6 df.loc [l] = rows
#       7 print (df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:885, in _LocationIndexer.__setitem__(self, key, value)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 885 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1883, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1880     indexer, missing = convert_missing_indexer(indexer)
#    1882     if missing:
# -> 1883         self._setitem_with_indexer_missing(indexer, value)
#    1884         return
#    1886 if name == "loc":
#    1887     # must come after setting of missing
#
# ...

# %%
print(len(rows))
# Out:
# 8
