# %%
import matplotlib.pyplot as plt
x=(range(0,10))
y=(range(-10,0))
plt.plot(x,y,color='red',lw=0.5)

# %%
import matplotlib.pyplot as plt
a=[0,-100,25,67,-323]
b=[0,3,7,3,9]
plt.plot(a,b,color='blue',lw=1)

# %%
x=['C','C++','Python','Java','JavaScript','Go']
y=[40,47,56,79,80,64]
plt.bar(x,y,color='orange',width=0.4)
# Out:
# <BarContainer object of 6 artists>

# %%
langs=['Python','C++','C#','Java','Java Script','R','Go']
votes=[40,35,55,62,70,89,20]
explodes=[0.2,0,0,0,0,0,0]
plt.pie(votes,labels=langs,explode=explodes,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x23372bed750>,
# ...
#  [Text(1.2261366304470696, 0.43195944656403457, 'Python'),
#   Text(0.6183687524219272, 0.9097362727890701, 'C++'),
#   Text(-0.18081224895238654, 1.0850377553932307, 'C#'),
#   Text(-1.0066601554668737, 0.44343582556601113, 'Java'),
#   Text(-0.8393133030843601, -0.7110226292218984, 'Java Script'),
#   Text(0.5064310403978092, -0.9764873789873543, 'R'),
#   Text(1.0842624706905901, -0.18540467807457672, 'Go')],
#  [Text(0.754545618736658, 0.2658211978855597, '10.78%'),
#   Text(0.3372920467755966, 0.49621978515767456, '9.43%'),
#   Text(-0.0986248630649381, 0.5918387756690349, '14.82%'),
#   Text(-0.5490873575273856, 0.24187408667236968, '16.71%'),
#   Text(-0.4578072562278327, -0.3878305250301263, '18.87%'),
#   Text(0.2762351129442595, -0.5326294794476477, '23.99%'),
#   Text(0.5914158931039581, -0.10112982440431456, '5.39%')])
